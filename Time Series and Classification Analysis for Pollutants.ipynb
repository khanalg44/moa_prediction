# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import NO2 data

# %%
data=pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/ad_viz_plotval_data.csv')

# %%
data['Daily Max 1-hour NO2 Concentration'].describe()
data.tail()
# Out:
#             Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 3203  12/27/2019    AQS  340130003    1                                34.2
# 3204  12/28/2019    AQS  340130003    1                                33.9
# 3205  12/29/2019    AQS  340130003    1                                34.9
# 3206  12/30/2019    AQS  340130003    1                                23.7
# 3207  12/31/2019    AQS  340130003    1                                25.5
#
#      UNITS  DAILY_AQI_VALUE         Site Name  DAILY_OBS_COUNT  \
# 3203   ppb               32  Newark Firehouse               24
# 3204   ppb               31  Newark Firehouse               24
# 3205   ppb               32  Newark Firehouse               21
# 3206   ppb               22  Newark Firehouse               24
# 3207   ppb               24  Newark Firehouse               24
#
#       PERCENT_COMPLETE  AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  CBSA_CODE  \
# 3203             100.0               42602  Nitrogen dioxide (NO2)      35620
# 3204             100.0               42602  Nitrogen dioxide (NO2)      35620
# 3205              88.0               42602  Nitrogen dioxide (NO2)      35620
# 3206             100.0               42602  Nitrogen dioxide (NO2)      35620
# 3207             100.0               42602  Nitrogen dioxide (NO2)      35620
#
#                                   CBSA_NAME  STATE_CODE       STATE  \
# 3203  New York-Newark-Jersey City, NY-NJ-PA          34  New Jersey
# 3204  New York-Newark-Jersey City, NY-NJ-PA          34  New Jersey
# 3205  New York-Newark-Jersey City, NY-NJ-PA          34  New Jersey
# 3206  New York-Newark-Jersey City, NY-NJ-PA          34  New Jersey
# 3207  New York-Newark-Jersey City, NY-NJ-PA          34  New Jersey
#
#       COUNTY_CODE COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 3203           13  Essex      40.720989      -74.192892
# 3204           13  Essex      40.720989      -74.192892
# 3205           13  Essex      40.720989      -74.192892
# 3206           13  Essex      40.720989      -74.192892
# 3207           13  Essex      40.720989      -74.192892

# %%
plt.plot(data['Date'][::10],data['Daily Max 1-hour NO2 Concentration'][::10])
plt.xticks(data['Date'][0::800]);
plt.xlabel('date')
plt.ylabel('NO2 Max concentration');
plt.title('Newark Fire Station NO2 concentration')
# Out:
# Text(0.5, 1.0, 'Newark Fire Station NO2 concentration')

# %% [markdown]
# ## Plot Autocorrelation Functions

# %%
def make_lag_df(df,feature,lag):
    lag_df = df.copy()
    lag_df[feature + '_lag'] = np.nan
    
    lag_df.loc[lag:,feature + '_lag'] = lag_df.loc[0:len(lag_df)-(lag+1),feature].values
    return lag_df

def plot_lag(df,feature,lag,ax=None):
    df = make_lag_df(df,feature,lag).dropna()
    if ax:
        ax.scatter(df[feature+'_lag'],df[feature])

        ax.plot(np.linspace(350,550,10),
                np.linspace(350,550,10),
               'k--', alpha = .6)

        ax.set_title("lag = " + str(lag),fontsize=12)
    else:
        plt.scatter(df[feature+'_lag'],df[feature])

        plt.plot(np.linspace(350,550,10),
                np.linspace(350,550,10),
               'k--', alpha = .6)

        plt.show()

def get_autocorr(df,feature,lag):
    df = make_lag_df(df,feature,lag)
    mean_y = df[feature].mean()
    
    
    
    y_ts = df[feature].values
    y_lags = df.dropna()[feature + '_lag'].values
    
    numerator = np.sum((y_ts[lag:] - mean_y)*(y_lags - mean_y))
    denom = np.sum(np.power(y_ts - mean_y,2))
    
    return numerator/denom

# %%
data_train= data.iloc[:-365,].copy()
data_test = data.drop(data_train.index).copy()

# %%
lags = np.arange(0,10,1)
print([get_autocorr(data_train,'Daily Max 1-hour NO2 Concentration',lag) for lag in lags])
# Out:
# [1.0, 0.40528052087480937, 0.15045939608783487, 0.13935415094417136, 0.17125724542873005, 0.15690986866737286, 0.19811621215910802, 0.20610313718593262, 0.17867050108863525, 0.14714844395360008]

# %%
data_diff=pd.DataFrame(data_train['Daily Max 1-hour NO2 Concentration'].diff()).dropna().reset_index(drop=True)

# %%
data_diff=pd.DataFrame(data_train['Daily Max 1-hour NO2 Concentration'].diff()).dropna().reset_index(drop=True)

# %%
## Plotting block
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="red", lw=4)]


n=50

data_autos = []

# get the autocorr.
for i in range(1,n,1):
    data_autos.append(get_autocorr(data_train,'Daily Max 1-hour NO2 Concentration',i))

# make a figure
plt.figure(figsize=(10,6))

# plot a horizontal line
plt.axhline(y=0, xmin=0, xmax=n, color = "blue")

# plot each autocorrelation against the lag
plt.scatter(range(1,n,1), 
           data_autos,
           c='b')

# Plot vertical lines
for i in range(1,n,1):
    plt.plot(i*np.ones(2),[0,data_autos[i-1]],'b')

# Add labels
plt.xlabel("Lag", fontsize=16)
plt.ylabel("ACF", fontsize=16)

# set tick marks
plt.xticks(np.arange(1,n,1), fontsize=8)
plt.yticks(fontsize=12)


data_diff_autos = []

# get the autocorr for the diff data

for i in range(1,n,1):
    data_diff_autos.append(get_autocorr(data_diff,'Daily Max 1-hour NO2 Concentration',i))

# plot each autocorrelation against the lag
plt.scatter(range(1,n,1), 
           data_diff_autos,
           c='r')

# Plot vertical lines
for i in range(1,n,1):
    plt.plot(i*np.ones(2),[0,data_diff_autos[i-1]],'r')
    
plt.legend(custom_lines, ['Daily NO2 Levels', 'Daily NO2 Differenced by 365'])

plt.show()

# %% [markdown]
# ## Plot Seasonal Projections

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %%
add_mod = ExponentialSmoothing(data_train['Daily Max 1-hour NO2 Concentration'],seasonal_periods=365, seasonal='add')

mul_mod = ExponentialSmoothing(data_train['Daily Max 1-hour NO2 Concentration'],seasonal_periods=365, seasonal='mul')

# %%
add_mod_fit = add_mod.fit()

# The multiplicative model
mul_mod_fit = mul_mod.fit()
# Out:
# C:\Users\plame\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\Users\plame\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub
# C:\Users\plame\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\plame\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
## Plot Them
fig,ax = plt.subplots(2,1,figsize=(12,16),sharex=True, sharey=True)

## The additive model
# training data
ax[0].plot(data_train['Daily Max 1-hour NO2 Concentration'].index, data_train['Daily Max 1-hour NO2 Concentration'].values, 
           'b-', label="Training Data")

# fitted values
ax[0].plot(data_train['Daily Max 1-hour NO2 Concentration'].index, add_mod_fit.fittedvalues, 
           'r-', label="Fitted Values")

# The test data
ax[0].plot(data_test['Daily Max 1-hour NO2 Concentration'].index, data_test['Daily Max 1-hour NO2 Concentration'].values,
            'b--', label="Test Data")
ax[0].plot(data_test['Daily Max 1-hour NO2 Concentration'].index, add_mod_fit.forecast(len(data_test['Daily Max 1-hour NO2 Concentration'])),
           'r--', label="Forecast")

ax[0].legend(fontsize=14)

ax[0].set_title("Additive Model",fontsize=18)
ax[0].set_ylabel('Daily Max 1-hour NO2 Concentration',fontsize=16)



## The multiplicative model
# training data
ax[1].plot(data_train['Daily Max 1-hour NO2 Concentration'].index, data_train['Daily Max 1-hour NO2 Concentration'].values, 
           'b-', label="Training Data")

# fitted values
ax[1].plot(data_train['Daily Max 1-hour NO2 Concentration'].index, mul_mod_fit.fittedvalues, 
           'r-', label="Fitted Values")

# The test data
ax[1].plot(data_test['Daily Max 1-hour NO2 Concentration'].index, data_test['Daily Max 1-hour NO2 Concentration'].values,
            'b--', label="Test Data")
ax[1].plot(data_test['Daily Max 1-hour NO2 Concentration'].index, mul_mod_fit.forecast(len(data_test['Daily Max 1-hour NO2 Concentration'])),
           'r--', label="Forecast")


ax[1].set_title("Multiplicative Model",fontsize=18)
ax[1].set_ylabel("Production",fontsize=16)
ax[1].set_xlabel("Day",fontsize=16)

plt.show()

# %%
data_NO2=data.iloc[:,4]
data_NO2
# Out:
# 0       23.0
# 1       44.0
# 2       52.0
# 3       40.0
# 4       51.0
#         ...
# 3203    34.2
# 3204    33.9
# 3205    34.9
# 3206    23.7
# 3207    25.5
# Name: Daily Max 1-hour NO2 Concentration, Length: 3208, dtype: float64

# %% [markdown]
# ## Ozone Data

# %%
data=pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/ad_viz_plotval_data_ozone.csv')
data.insert(6,'Daily Max 1-hour NO2 Concentration',data_NO2)
data
# Out:
#             Date  Source    Site ID  POC  \
# 0     06/01/2009     AQS  340130003    1
# 1     06/02/2009     AQS  340130003    1
# 2     06/03/2009     AQS  340130003    1
# 3     06/04/2009     AQS  340130003    1
# 4     06/05/2009     AQS  340130003    1
# ...          ...     ...        ...  ...
# 3922  05/16/2020  AirNow  340130003    1
# 3923  05/17/2020  AirNow  340130003    1
# 3924  05/18/2020  AirNow  340130003    1
# 3925  05/19/2020  AirNow  340130003    1
# 3926  05/20/2020  AirNow  340130003    1
#
#       Daily Max 8-hour Ozone Concentration UNITS  \
# 0                                    0.043   ppm
# 1                                    0.044   ppm
# 2                                    0.029   ppm
# 3                                    0.018   ppm
# 4                                    0.025   ppm
# ...                                    ...   ...
# 3922                                 0.045   ppm
# 3923                                 0.043   ppm
# 3924                                 0.039   ppm
# 3925                                 0.039   ppm
# 3926                                 0.037   ppm
#
#       Daily Max 1-hour NO2 Concentration  DAILY_AQI_VALUE         Site Name  \
# 0                                   23.0               40  Newark Firehouse
# 1                                   44.0               41  Newark Firehouse
# 2                                   52.0               27  Newark Firehouse
# 3                                   40.0               17  Newark Firehouse
# 4                                   51.0               23  Newark Firehouse
# ...                                  ...              ...               ...
# 3922                                 NaN               42  Newark Firehouse
# 3923                                 NaN               40  Newark Firehouse
# 3924                                 NaN               36  Newark Firehouse
# 3925                                 NaN               36  Newark Firehouse
# 3926                                 NaN               34  Newark Firehouse
#
#       DAILY_OBS_COUNT  ...  AQS_PARAMETER_CODE  AQS_PARAMETER_DESC CBSA_CODE  \
# 0                  17  ...               44201               Ozone     35620
# 1                  17  ...               44201               Ozone     35620
# 2                  17  ...               44201               Ozone     35620
# 3                  17  ...               44201               Ozone     35620
# 4                  17  ...               44201               Ozone     35620
# ...               ...  ...                 ...                 ...       ...
# 3922               24  ...               44201               Ozone     35620
# 3923               24  ...               44201               Ozone     35620
# 3924               24  ...               44201               Ozone     35620
# 3925               24  ...               44201               Ozone     35620
# 3926               21  ...               44201               Ozone     35620
#
#                                   CBSA_NAME STATE_CODE       STATE  \
# 0     New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 1     New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 2     New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 3     New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 4     New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# ...                                     ...        ...         ...
# 3922  New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 3923  New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 3924  New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 3925  New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
# 3926  New York-Newark-Jersey City, NY-NJ-PA         34  New Jersey
#
#      COUNTY_CODE  COUNTY SITE_LATITUDE  SITE_LONGITUDE
# 0             13   Essex     40.720989      -74.192892
# 1             13   Essex     40.720989      -74.192892
# 2             13   Essex     40.720989      -74.192892
# 3             13   Essex     40.720989      -74.192892
# 4             13   Essex     40.720989      -74.192892
# ...          ...     ...           ...             ...
# 3922          13   Essex     40.720989      -74.192892
# 3923          13   Essex     40.720989      -74.192892
# 3924          13   Essex     40.720989      -74.192892
# 3925          13   Essex     40.720989      -74.192892
# 3926          13   Essex     40.720989      -74.192892
#
# [3927 rows x 21 columns]

# %%
plt.plot(data['Date'][::10],data['Daily Max 8-hour Ozone Concentration'][::10])
plt.xticks(data['Date'][0::800]);
plt.xlabel('date')
plt.ylabel('Daily Max 8-hour Ozone Concentration');
plt.title('Newark Fire Station ozone concentration')
# Out:
# Text(0.5, 1.0, 'Newark Fire Station ozone concentration')

# %%
data_train= data.iloc[:-365,].copy()
data_test = data.drop(data_train.index).copy()

lags = np.arange(0,10,1)
print([get_autocorr(data_train,'Daily Max 8-hour Ozone Concentration',lag) for lag in lags])

data_diff=pd.DataFrame(data_train['Daily Max 8-hour Ozone Concentration'].diff()).dropna().reset_index(drop=True)

data_diff=pd.DataFrame(data_train['Daily Max 8-hour Ozone Concentration'].diff()).dropna().reset_index(drop=True)

## Plotting block
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="red", lw=4)]


n=50

data_autos = []

# get the autocorr.
for i in range(1,n,1):
    data_autos.append(get_autocorr(data_train,'Daily Max 8-hour Ozone Concentration',i))

# make a figure
plt.figure(figsize=(10,6))

# plot a horizontal line
plt.axhline(y=0, xmin=0, xmax=n, color = "blue")

# plot each autocorrelation against the lag
plt.scatter(range(1,n,1), 
           data_autos,
           c='b')

# Plot vertical lines
for i in range(1,n,1):
    plt.plot(i*np.ones(2),[0,data_autos[i-1]],'b')

# Add labels
plt.xlabel("Lag", fontsize=16)
plt.ylabel("ACF", fontsize=16)

# set tick marks
plt.xticks(np.arange(1,n,1), fontsize=8)
plt.yticks(fontsize=12)


data_diff_autos = []

# get the autocorr for the diff data

for i in range(1,n,1):
    data_diff_autos.append(get_autocorr(data_diff,'Daily Max 8-hour Ozone Concentration',i))

# plot each autocorrelation against the lag
plt.scatter(range(1,n,1), 
           data_diff_autos,
           c='r')

# Plot vertical lines
for i in range(1,n,1):
    plt.plot(i*np.ones(2),[0,data_diff_autos[i-1]],'r')
    
plt.legend(custom_lines, ['Daily ozone Levels', 'Daily ozone Differenced by 365'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-285-869c93b35438> in <module>()
#       3
#       4 lags = np.arange(0,10,1)
# ----> 5 print([get_autocorr(data_train,'Daily Max 8-hour Ozone Concentration',lag) for lag in lags])
#       6
#       7 data_diff=pd.DataFrame(data_train['Daily Max 8-hour Ozone Concentration'].diff()).dropna().reset_index(drop=True)
#
# <ipython-input-285-869c93b35438> in <listcomp>(.0)
#       3
#       4 lags = np.arange(0,10,1)
# ----> 5 print([get_autocorr(data_train,'Daily Max 8-hour Ozone Concentration',lag) for lag in lags])
#       6
#       7 data_diff=pd.DataFrame(data_train['Daily Max 8-hour Ozone Concentration'].diff()).dropna().reset_index(drop=True)
#
# <ipython-input-5-135a28be8fae> in get_autocorr(df, feature, lag)
#      34     y_lags = df.dropna()[feature + '_lag'].values
#      35
# ---> 36     numerator = np.sum((y_ts[lag:] - mean_y)*(y_lags - mean_y))
#      37     denom = np.sum(np.power(y_ts - mean_y,2))
#      38
#
# ValueError: operands could not be broadcast together with shapes (3562,) (3208,)

# %%
add_mod = ExponentialSmoothing(data_train['Daily Max 8-hour Ozone Concentration'],seasonal_periods=365, seasonal='add')

#mul_mod = ExponentialSmoothing(data_train['Daily Max 8-hour Ozone Concentration'],seasonal_periods=365, seasonal='mul')

# %%
add_mod_fit = add_mod.fit()

# The multiplicative model
#mul_mod_fit = mul_mod.fit()

# %%
## Plot Them
fig,ax = plt.subplots(1,1,figsize=(12,8),sharex=True, sharey=True)

## The additive model
# training data
ax.plot(data_train['Daily Max 8-hour Ozone Concentration'].index, data_train['Daily Max 8-hour Ozone Concentration'].values, 
        'b-', label="Training Data")

# ted values
ax.plot(data_train['Daily Max 8-hour Ozone Concentration'].index, add_mod_fit.fittedvalues, 
        'r-', label="Fitted Values")

#  test data
ax.plot(data_test['Daily Max 8-hour Ozone Concentration'].index, data_test['Daily Max 8-hour Ozone Concentration'].values,
         'b--', label="Test Data")
ax.plot(data_test['Daily Max 8-hour Ozone Concentration'].index, add_mod_fit.forecast(len(data_test['Daily Max 8-hour Ozone Concentration'])),
        'r--', label="Forecast")

ax.legend(fontsize=14)

ax.set_title("Additive Model",fontsize=18)
ax.set_ylabel('Daily Max 8-hour Ozone Concentration',fontsize=16)



## The multiplicative model
# # training data
# ax[1].plot(data_train['Daily Max 8-hour Ozone Concentration'].index, data_train['Daily Max 8-hour Ozone Concentration'].values, 
#            'b-', label="Training Data")

# # fitted values
# ax[1].plot(data_train['Daily Max 8-hour Ozone Concentration'].index, mul_mod_fit.fittedvalues, 
#            'r-', label="Fitted Values")

# # The test data
# ax[1].plot(data_test['Daily Max 8-hour Ozone Concentration'].index, data_test['Daily Max 8-hour Ozone Concentration'].values,
#             'b--', label="Test Data")
# ax[1].plot(data_test['Daily Max 8-hour Ozone Concentration'].index, mul_mod_fit.forecast(len(data_test['Daily Max 8-hour Ozone Concentration'])),
#            'r--', label="Forecast")


# ax[1].set_title("Multiplicative Model",fontsize=18)
# ax[1].set_ylabel("Production",fontsize=16)
# ax[1].set_xlabel("Day",fontsize=16)

plt.show()

# %% [markdown]
# # Data by County

# %%
county=pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/annual_aqi_by_county_2020.csv')
county=pd.DataFrame.append(county,pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/annual_aqi_by_county_2019.csv'))

# %%
county=pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/annual_conc_by_monitor_2020.csv')

# %%
county[(county['State Code']==36) & (county['County Code']==5)]
# Out:
#       State Code  County Code  Site Num  Parameter Code  POC  Latitude  \
# 7839          36            5        80           88501    3  40.83606
# 7840          36            5        80           88501    3  40.83606
# 7841          36            5        80           88502    3  40.83606
# 7842          36            5        80           88502    3  40.83606
# 7843          36            5       110           42401    1  40.81600
# ...          ...          ...       ...             ...  ...       ...
# 8154          36            5       133           68109    1  40.86790
# 8155          36            5       133           88101    1  40.86790
# 8156          36            5       133           88101    1  40.86790
# 8157          36            5       133           88101    1  40.86790
# 8158          36            5       133           88101    1  40.86790
#
#       Longitude  Datum                          Parameter Name  \
# 7839  -73.92009  WGS84                          PM2.5 Raw Data
# 7840  -73.92009  WGS84                          PM2.5 Raw Data
# 7841  -73.92009  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 7842  -73.92009  WGS84  Acceptable PM2.5 AQI & Speciation Mass
# 7843  -73.90200  WGS84                          Sulfur dioxide
# ...         ...    ...                                     ...
# 8154  -73.87809  WGS84                     Elapsed Sample Time
# 8155  -73.87809  WGS84                PM2.5 - Local Conditions
# 8156  -73.87809  WGS84                PM2.5 - Local Conditions
# 8157  -73.87809  WGS84                PM2.5 - Local Conditions
# 8158  -73.87809  WGS84                PM2.5 - Local Conditions
#
#      Sample Duration  ... 75th Percentile 50th Percentile 10th Percentile  \
# 7839          1 HOUR  ...             8.8             6.4             3.1
# 7840   24-HR BLK AVG  ...             8.7             6.4             4.2
# 7841          1 HOUR  ...             9.9             6.8             2.5
# 7842   24-HR BLK AVG  ...             9.4             7.1             3.7
# 7843          1 HOUR  ...             1.7             1.2             0.5
# ...              ...  ...             ...             ...             ...
# 8154         24 HOUR  ...          1439.0          1439.0          1439.0
# 8155         24 HOUR  ...             8.5             7.4             3.2
# 8156         24 HOUR  ...             8.5             7.4             3.2
# 8157         24 HOUR  ...             8.5             7.4             3.2
# 8158         24 HOUR  ...             8.5             7.4             3.2
#
#       Local Site Name                                         Address  \
# 7839       MORRISANIA          MORRISANIA CENTER, 1225-57 GERARD AVE.
# 7840       MORRISANIA          MORRISANIA CENTER, 1225-57 GERARD AVE.
# 7841       MORRISANIA          MORRISANIA CENTER, 1225-57 GERARD AVE.
# 7842       MORRISANIA          MORRISANIA CENTER, 1225-57 GERARD AVE.
# 7843            IS 52                           IS 52    681 KELLY ST
# ...               ...                                             ...
# 8154  PFIZER LAB SITE  200TH STREET AND SOUTHERN BOULDVARD Pfizer Lab
# 8155  PFIZER LAB SITE  200TH STREET AND SOUTHERN BOULDVARD Pfizer Lab
# 8156  PFIZER LAB SITE  200TH STREET AND SOUTHERN BOULDVARD Pfizer Lab
# 8157  PFIZER LAB SITE  200TH STREET AND SOUTHERN BOULDVARD Pfizer Lab
# 8158  PFIZER LAB SITE  200TH STREET AND SOUTHERN BOULDVARD Pfizer Lab
#
#      State Name  County Name  City Name  \
# 7839   New York        Bronx   New York
# 7840   New York        Bronx   New York
# 7841   New York        Bronx   New York
# 7842   New York        Bronx   New York
# 7843   New York        Bronx   New York
# ...         ...          ...        ...
# 8154   New York        Bronx   New York
# 8155   New York        Bronx   New York
# 8156   New York        Bronx   New York
# 8157   New York        Bronx   New York
# 8158   New York        Bronx   New York
#
#                                   CBSA Name  Date of Last Change
# 7839  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 7840  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 7841  New York-Newark-Jersey City, NY-NJ-PA           2020-05-07
# 7842  New York-Newark-Jersey City, NY-NJ-PA           2020-05-07
# 7843  New York-Newark-Jersey City, NY-NJ-PA           2020-05-07
# ...                                     ...                  ...
# 8154  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 8155  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 8156  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 8157  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
# 8158  New York-Newark-Jersey City, NY-NJ-PA           2020-05-12
#
# [320 rows x 55 columns]

# %%
def prepare(df,cols):
    df[cols] = df[cols].astype(str)
    
    dummies = pd.get_dummies(df[cols])
    
    new_df = pd.concat([df[[c for c in df.columns if c not in cols]],dummies],axis=1, sort=False)
    
    return new_df

# %%
county=prepare(county,'State Name')

# %%
def plot_bound(clf,X,y,pts = False):
    plt.figure(figsize = (10,10))
    coefs = clf.coef_[0]
    intercept = clf.intercept_[0]
    
    if coefs[0] != 0:
        plt.plot(np.linspace(np.min(X[:,0]),np.max(X[:,0]),1000),
                     (-intercept/coefs[1])-(coefs[0]/coefs[1])*np.linspace(np.min(X[:,0]),np.max(X[:,0]),1000),
                        'k',label = "SVM Boundary")
    else:
        plt.plot((-intercept/coefs[0])*np.ones(1000),
                     np.linspace(np.min(X[:,1],np.max(X[:,1]),1000),
                        'k'),label = "SVM Boundary")
        
    if pts:
        plt.scatter(X[y == 0,0],X[y == 0,1],color="orange",label="0",s=50)
        plt.scatter(X[y == 1,0],X[y == 1,1],color="blue",label="1", alpha = 1,s=50)

        plt.legend(fontsize=16)

    plt.xlabel("$x_1$",fontsize=16)
    plt.ylabel("$x_2$",fontsize=16)
    plt.title("Decision Boundary",fontsize = 20)
    

    plt.show()

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

max_margin = Pipeline([('scaler', StandardScaler()), ('svc', LinearSVC(C=1,loss='squared_hinge'))])

# %%
X=np.array(county[['50th Percentile','90th Percentile']])
y=np.array(county['North Carolina'])

# %%
plt.figure(figsize = (12,8))
           
plt.scatter(X[y == 0,0],X[y == 0,1],color="orange",label="0")
plt.scatter(X[y == 1,0],X[y == 1,1],color="blue",label="1", alpha = .6)

plt.legend(fontsize=16)
plt.xlim(0,2000)
plt.ylim(0,2000)

plt.xlabel("$x_1$",fontsize=16)
plt.ylabel("$x_2$",fontsize=16)
plt.title("AQI data",fontsize = 20)

plt.show()

# %%
max_margin.fit(X,y);

# %%
#max_margin.named_steps['svc']

# %%
plot_bound(max_margin.named_steps['svc'],X,y,True)

# %%
# X=np.zeros([6,6])
# #fig,axes=plt.subplots(6,6)

# for i in range(len(county.columns[10:12])):
#      for j in range(len(county.columns[10:12])):
            
#             name=county.columns[10:12]

#             X=np.array(county[[name[i],name[j]]])
#             y=np.array(county['New York'])
#             max_margin.fit(X,y)
#             plot_bound(max_margin.named_steps['svc'],X,y,True)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
max_depth = 4
tree_clf = DecisionTreeClassifier(max_depth = max_depth,random_state = 614)

# Fit the tree
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=614, splitter='best')

# %%
def plot_bound_tree(clf,X,y,pts = False):
    plot_step = 100

    x_min, x_max = X[:, 0].min() - .2, X[:, 0].max() + .2
    y_min, y_max = X[:, 1].min() - .2, X[:, 1].max() + .2
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),np.arange(y_min, y_max, plot_step))


    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize = (12,10))
    cs = plt.contourf(xx, yy, Z, colors=['orange','white','blue','white'])

    if pts:
        plt.scatter(X[y == 0,0],X[y == 0,1],color="black",ec="white",label="0",s=50)
        plt.scatter(X[y == 1,0],X[y == 1,1],color="white",label="1", alpha = 1,s=50)

        plt.legend(fontsize=16)

    plt.xlabel("$x_1$",fontsize=16)
    plt.ylabel("$x_2$",fontsize=16)
    plt.title("AQI data set",fontsize = 20)

    plt.show()

# %%
# Plot the boundary
plot_bound_tree(tree_clf,X,y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_clf = RandomForestClassifier(max_depth = max_depth)

forest_clf.fit(X,y)

plot_bound_tree(forest_clf,X,y)

# %% [markdown]
# ## List of Data Stations

# %%
sites=pd.read_csv('https://raw.githubusercontent.com/yilmazduygu/gretta-grettas/master/aqs_sites.csv')

# %%
sites[(sites["State Name"]=="New York") & (sites["City Name"]=='New York')]
# Out:
#       State Code  County Code  Site Number   Latitude  Longitude  Datum  \
# 11926         36            5            3  40.831767 -73.903748  WGS84
# 11927         36            5            6  40.878054 -73.890397  WGS84
# 11928         36            5            9  40.806942 -73.796229  WGS84
# 11929         36            5           12  40.859165 -73.914009  WGS84
# 11930         36            5           22  40.810555 -73.907621  WGS84
# ...          ...          ...          ...        ...        ...    ...
# 12467         36           85          109  40.591111 -74.158611  WGS84
# 12468         36           85          111  40.580270 -74.198320  WGS84
# 12469         36           85          114  40.631370 -74.157320  WGS84
# 12470         36           85          131  40.588060 -74.168820  WGS84
# 12471         36           85          132  40.580560 -74.151780  WGS84
#
#        Elevation     Land Use       Location Setting Site Established Date  \
# 11926       41.0  RESIDENTIAL  URBAN AND CENTER CITY            1968-01-01
# 11927       43.0  RESIDENTIAL  URBAN AND CENTER CITY            1968-01-01
# 11928        3.0  RESIDENTIAL               SUBURBAN            1968-01-01
# 11929       46.0  RESIDENTIAL  URBAN AND CENTER CITY            1965-01-01
# 11930        9.0  RESIDENTIAL  URBAN AND CENTER CITY            1965-01-01
# ...          ...          ...                    ...                   ...
# 12467        0.0   COMMERCIAL               SUBURBAN            1994-10-01
# 12468        3.0   COMMERCIAL               SUBURBAN            1999-07-05
# 12469       16.0   COMMERCIAL  URBAN AND CENTER CITY            2001-01-01
# 12470        5.0   INDUSTRIAL  URBAN AND CENTER CITY            2001-12-01
# 12471       44.0   COMMERCIAL               SUBURBAN            2002-04-01
#
#        ...                                      Owning Agency  \
# 11926  ...  New York State Department Of Environmental Con...
# 11927  ...              US EPA National Exposure Research Lab
# 11928  ...  New York State Department Of Environmental Con...
# 11929  ...  New York State Department Of Environmental Con...
# 11930  ...  New York State Department Of Environmental Con...
# ...    ...                                                ...
# 12467  ...  New York State Department Of Environmental Con...
# 12468  ...  New York State Department Of Environmental Con...
# 12469  ...  New York State Department Of Environmental Con...
# 12470  ...  New York State Department Of Environmental Con...
# 12471  ...  New York State Department Of Environmental Con...
#
#                  Local Site Name                                   Address  \
# 11926                        NaN  MORRISANIA HEALTH CENTER,1309 FULTON AV.
# 11927                        NaN  BRONX HS OF SCIENCE, 205 ST.&GOULDEN AVE
# 11928                        NaN                  FORT SCHUYLER ,USNMC RTC
# 11929                        NaN  NY UNIV. (HGTS CAMPUS),1911 OSBORN PLACE
# 11930                        NaN      SAMUEL GOMPERS HS, 445 SOUTHERN BLVD
# ...                          ...                                       ...
# 12467  PS 69  FRESHKILLS NETWORK                  PS 69  144 KEATING PLACE
# 12468            FRESHKILLS WEST   FRESHKILLS WEST   310 West Service Road
# 12469                      PS 44                  PS 44   80 MAPLE PARKWAY
# 12470            FRESHKILLS EAST                      2470 RICHMOND AVENUE
# 12471     LATOURETTE GOLF COURSE    LaTourette     1001 RICHMOND HILL ROAD
#
#        Zip Code State Name  County Name City Name  \
# 11926       NaN   New York        Bronx  New York
# 11927   10468.0   New York        Bronx  New York
# 11928   10465.0   New York        Bronx  New York
# 11929   10453.0   New York        Bronx  New York
# 11930   10455.0   New York        Bronx  New York
# ...         ...        ...          ...       ...
# 12467       NaN   New York     Richmond  New York
# 12468   10314.0   New York     Richmond  New York
# 12469   10303.0   New York     Richmond  New York
# 12470   10314.0   New York     Richmond  New York
# 12471   10314.0   New York     Richmond  New York
#
#                                    CBSA Name Tribe Name Extraction Date
# 11926  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 11927  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 11928  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 11929  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 11930  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# ...                                      ...        ...             ...
# 12467  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 12468  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 12469  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 12470  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
# 12471  New York-Newark-Jersey City, NY-NJ-PA        NaN      2020-05-19
#
# [133 rows x 28 columns]
